# %% [markdown]
# # 🚀 Assignment 2: Applied Python for AI & Data Science
# **Machine Learning & AI BootCamp**
# *Instructor: Fahd*
#
# ---
#
# ### 🎯 Assignment Overview
# Welcome to **Assignment 2**! This assignment provides unique, real-world mini-scenarios based on the concepts taught across **Class 2, Class 3, and Class 4**.
#
# Instead of traditional generic math puzzles, you will solve practical challenges inspired by **AI prompt token calculations, GPU monitor metrics, IoT sensor parsing, dataset vocabulary processing, model benchmarks, and server log analysis**.
#
# ---
#
# ### 📌 Instructions:
# 1. Work through each exercise sequentially.
# 2. Complete the code in each code cell directly underneath the `# TODO:` comments.
# 3. Run each cell (`Shift + Enter`) to verify that your output matches the **Expected Output**.
# 4. Every problem is beginner-friendly and designed to build your problem-solving skills!

# %% [markdown]
# ---
# # 📘 Part 1: Variables, Data Types & Text Manipulation (Class 2)
#
# Practical applications of arithmetic, type casting, string slicing, and string manipulation.

# %% [markdown]
# ## Section 1: Practical Arithmetic & Type Casting

# %% [markdown]
# ### Exercise 1.1: AI LLM Prompt & Completion Cost Estimator
# When calling an AI Large Language Model (LLM) API, costs are charged per 1,000 tokens:
# - **Prompt Token Price**: $0.002 per 1,000 tokens
# - **Completion Token Price**: $0.006 per 1,000 tokens
#
# Given a user session with:
# - `prompt_tokens = 1500`
# - `completion_tokens = 600`
#
# **Tasks:**
# 1. Calculate `prompt_cost = (prompt_tokens / 1000) * 0.002`.
# 2. Calculate `completion_cost = (completion_tokens / 1000) * 0.006`.
# 3. Calculate `total_cost = prompt_cost + completion_cost`.
# 4. Print all three values formatted as shown below.
#
# **Expected Output:**
# ```text
# Prompt Cost: $0.0030
# Completion Cost: $0.0036
# Total API Cost: $0.0066
# ```

# %%
prompt_tokens = 1500
completion_tokens = 600

# TODO: Calculate prompt_cost, completion_cost, and total_cost, then print
prompt_cost = (prompt_tokens / 1000) * 0.002
completion_cost = (completion_tokens /1000) * 0.006
total_cost = prompt_cost + completion_cost

print(f"prompt Cost: ${prompt_cost}")
print(f"completion cost: ${completion_cost}")
print(f"Total API cost: ${total_cost}")

# %% [markdown]
# ### Exercise 1.2: Cloud GPU Training Uptime Tracker
# A deep learning model has been training continuously on a cloud GPU instance for `total_training_hours = 86`.
#
# **Tasks:**
# 1. Use floor division (`//`) by 24 to find the full number of **days** of training.
# 2. Use modulo (`%`) by 24 to find the remaining **hours**.
# 3. Print the formatted message.
#
# **Expected Output:**
# ```text
# Training Uptime: 3 day(s) and 14 hour(s)
# ```

# %%
total_training_hours = 86

# TODO: Calculate days and remaining hours using // and %, then print
days = total_training_hours // 24
hours = total_training_hours % 24
print(f"Training Uptime: {days} day(s) and {hours} hour(s)")

# %% [markdown]
# ### Exercise 1.3: IoT Sensor Data Packet Parser
# An IoT temperature sensor sends raw readings as string values:
# `device_id_str = "108"`
# `temp_reading_str = "98.4"`
# `calibration_offset = 1.6`
#
# **Tasks:**
# 1. Convert `device_id_str` to an integer (`int`).
# 2. Convert `temp_reading_str` to a floating-point number (`float`).
# 3. Compute the `calibrated_temp = converted_temp + calibration_offset`.
# 4. Print the Device ID, the calibrated temperature, and the data type of `calibrated_temp`.
#
# **Expected Output:**
# ```text
# Device ID: 108 | Calibrated Temp: 100.0 | Data Type: <class 'float'>
# ```

# %%
device_id_str = "108"
temp_reading_str = "98.4"
calibration_offset = 1.6

# TODO: Convert types, calculate calibrated_temp, and print result
device = int(device_id_str)
reading  = float(temp_reading_str)
calibrated_temp = reading + calibration_offset
temp = float(calibrated_temp)
print(f"Device ID: {device} | Calibrated Temp :{temp} | Data Type: {type(calibrated_temp)}")

# %% [markdown]
# ## Section 2: Data Cleaning & String Manipulation

# %% [markdown]
# ### Exercise 2.1: Image Dataset Filename Cleaner
# In computer vision datasets, filenames often contain irregular whitespace or uppercase extensions:
# `raw_filename = "   DATASET_sample_golden_retriever.JPEG   "`
#
# **Tasks:**
# 1. Strip leading and trailing whitespace using `.strip()`.
# 2. Convert the entire filename to lowercase using `.lower()`.
# 3. Replace the extension `".jpeg"` with `".png"`.
# 4. Print the cleaned filename.
#
# **Expected Output:**
# ```text
# Cleaned Filename: dataset_sample_golden_retriever.png
# ```

# %%
raw_filename = "   DATASET_sample_golden_retriever.JPEG   "

# TODO: Strip whitespace, convert to lowercase, replace extension, and print
striped = raw_filename.strip()
striped = striped.lower()
new_text = striped.replace(".jpeg",".png")
print(new_text)

# %% [markdown]
# ### Exercise 2.2: Slicing Usernames & Domains from AI Chat Handles
# Given an AI chat handle: `handle = "@alex_ai_expert"`
#
# **Tasks:**
# 1. Slice off the `@` symbol at the beginning (print from index 1 onward).
# 2. Slice and print the first 4 characters of the name (index 1 to 5).
# 3. Check if the handle starts with `"@"` using `.startswith("@")` and print the boolean result.
#
# **Expected Output:**
# ```text
# Handle without @: alex_ai_expert
# Extracted name: alex
# Starts with @: True
# ```

# %%
handle = "@alex_ai_expert"

# TODO: Perform slicing and startswith check, then print
slice  = handle
print("handle without @ :",handle[1:])
print("Extracted Name :",handle[1:5])
ok = False
if handle[0] == '@':
    ok = True

print("starts with @:",ok)

# %% [markdown]
# ### Exercise 2.3: Reversing an AI Encrypted Token
# An autonomous AI agent transmits a reversed verification token:
# `encrypted_token = "tnedutS_IB_LM"`
#
# - Reverse the string using slice step notation `[::-1]`.
# - Print the decrypted token.
#
# **Expected Output:**
# ```text
# Decrypted Token: ML_BI_Student
# ```

# %%
encrypted_token = "tnedutS_IB_LM"

# TODO: Reverse encrypted_token using slicing [::-1] and print
print("Decrypted Token :",encrypted_token[::-1])

# %% [markdown]
# ---
# # 📗 Part 2: Decision Making, Loops, Functions & Structures (Class 3)
#
# Conditionals, iterative processes, functions, Lists, Tuples, Sets, Dictionaries, and List Comprehensions.

# %% [markdown]
# ## Section 3: Conditional Logic & Safety Triggers

# %% [markdown]
# ### Exercise 3.1: Server GPU Temperature Safety Guard
# Write an `if-elif-else` conditional monitor for a machine learning server with `gpu_temp = 83` (°C):
# - If `gpu_temp >= 90`: Print `"CRITICAL: Thermal throttling activated!"`
# - If `gpu_temp >= 80`: Print `"WARNING: High temperature, fans set to 100%!"`
# - If `gpu_temp >= 50`: Print `"NORMAL: GPU running smoothly."`
# - Else: Print `"IDLE: GPU is cool."`
#
# **Expected Output:**
# ```text
# GPU Temp: 83°C -> WARNING: High temperature, fans set to 100%!
# ```

# %%
gpu_temp = 83

# TODO: Implement the GPU temperature monitor and print status
if gpu_temp >= 90:
    print("CRITICAL: Thermal throttling activated!")
elif gpu_temp >=80:
    print(f"Gpu Temp:{gpu_temp} Warning: HIGH temparature, fans set to 100%!")
elif gpu_temp >= 50:
    print("Normal : GPU running smoothly.")
else:
    print("IDLE: GPU is cool")

# %% [markdown]
# ### Exercise 3.2: Model Accuracy Tier Classifier
# Given a test accuracy `accuracy_score = 0.93` (93%):
# - If `accuracy_score >= 0.95`: Tier `"Production Ready (S-Tier)"`
# - If `accuracy_score >= 0.90`: Tier `"Acceptable Candidate (A-Tier)"`
# - If `accuracy_score >= 0.80`: Tier `"Needs Tuning (B-Tier)"`
# - Else: Tier `"Retrain Required (F-Tier)"`
#
# **Expected Output:**
# ```text
# Accuracy: 93.0% -> Tier: Acceptable Candidate (A-Tier)
# ```

# %%
accuracy_score = 0.93

# TODO: Determine model tier and print with percentage
if accuracy_score >= 0.95:
    print("production Ready (S-Tier)")
elif accuracy_score >=0.90:
    print("Accurate candidate (A-tier)")
elif accuracy_score >=0.80:
    print("Needs Tuning (B-tier)")
else:
    print("retrain Required (f-tier)")

# %% [markdown]
# ## Section 4: Loops & Early Stopping Simulation

# %% [markdown]
# ### Exercise 4.1: Model Training Epoch Simulator (`for` loop)
# Simulate training a neural network for 5 epochs using a `for` loop over `range(1, 6)`:
# - Start initial loss at `0.75`.
# - In each epoch `i`, calculate `current_loss = round(0.75 - (i * 0.10), 2)`.
# - Print: `Epoch 1/5 | Loss: 0.65`, `Epoch 2/5 | Loss: 0.55`, etc.
#
# **Expected Output:**
# ```text
# Epoch 1/5 | Loss: 0.65
# Epoch 2/5 | Loss: 0.55
# Epoch 3/5 | Loss: 0.45
# Epoch 4/5 | Loss: 0.35
# Epoch 5/5 | Loss: 0.25
# ```

# %%
# TODO: Loop from epoch 1 to 5, calculate current_loss, and print
loss = 0.75
for i in range(1,6):
    current_loss = round(0.75 - (i * 0.10),2)
    print(f"Epoch {i}/5 | Loss:{current_loss}")

# %% [markdown]
# ### Exercise 4.2: Drone Battery Discharge (`while` loop)
# A video delivery drone starts with `battery_level = 100` (%).
# - In a `while battery_level > 20` loop:
#   - Print `f"Drone Flying... Battery at {battery_level}%"`.
#   - Decrease `battery_level` by `20` in each step.
# - When the loop ends, print `"Low Battery Alert: Returning to charging dock!"`.
#
# **Expected Output:**
# ```text
# Drone Flying... Battery at 100%
# Drone Flying... Battery at 80%
# Drone Flying... Battery at 60%
# Drone Flying... Battery at 40%
# Low Battery Alert: Returning to charging dock!
# ```

# %%
battery_level = 100

# TODO: Write while loop checking battery_level > 20, decrementing by 20
while(battery_level > 20):
    print(f"Drone Flying... Battery at {battery_level}")
    battery_level -= 20
print("Low battery Alert : Returning to charging dock!")

# %% [markdown]
# ### Exercise 4.3: Early Stopping Mechanism (`break` and `continue`)
# You are iterating through validation losses across 7 checkpoints:
# `val_losses = [0.88, 0.82, 0.79, 0.65, 0.38, 0.32, 0.28]`
#
# **Tasks:**
# Loop through `val_losses`:
# 1. If loss is greater than `0.80`, skip reporting it using `continue`.
# 2. If loss drops below `0.40`, print `f"Early stopping triggered at loss {loss}! Model converged."` and terminate the loop using `break`.
# 3. Otherwise, print `f"Checkpoint validation loss: {loss}"`.
#
# **Expected Output:**
# ```text
# Checkpoint validation loss: 0.79
# Checkpoint validation loss: 0.65
# Early stopping triggered at loss 0.38! Model converged.
# ```

# %%
val_losses = [0.88, 0.82, 0.79, 0.65, 0.38, 0.32, 0.28]
# TODO: Iterate through val_losses with continue (>0.80) and break (<0.40)
for i in val_losses:
    if i>0.80:
        continue
    if i<0.40:
        print(f"Early stopping at loss{i}!")
        print("model converged")
        break
    else:
        print(f"checkpoint validition loss: {i}")

# %% [markdown]
# ## Section 5: Custom Functions & Default Arguments

# %% [markdown]
# ### Exercise 5.1: Model Accuracy Metric Function
# Define a function `calculate_accuracy(correct_predictions, total_samples)`:
# - Computes accuracy percentage: `(correct_predictions / total_samples) * 100`.
# - Returns a formatted string: `f"Accuracy: {acc:.1f}% ({correct_predictions}/{total_samples})"`.
# - Test by calling `calculate_accuracy(184, 200)` and print the result.
#
# **Expected Output:**
# ```text
# Accuracy: 92.0% (184/200)
# ```

# %%
# TODO: Define calculate_accuracy(correct_predictions, total_samples) and test it
def calculate(correct_predictions,total_samples):
    accuracy = (correct_predictions / total_samples) * 100
    return f"accuracy: {accuracy:.1f} % ({correct_predictions}/{total_samples})"
print(calculate(184,200))

# %% [markdown]
# ### Exercise 5.2: Hyperparameter Builder with Defaults
# Define a function `build_hyperparameters(learning_rate=0.001, batch_size=32, optimizer="Adam")`:
# - Returns a summary string: `f"Config -> LR: {learning_rate}, Batch: {batch_size}, Optimizer: {optimizer}"`.
# - Test 1: Call `build_hyperparameters()` (using all default parameters).
# - Test 2: Call `build_hyperparameters(learning_rate=0.01, batch_size=64, optimizer="SGD")`.
# - Print both configurations.
#
# **Expected Output:**
# ```text
# Default: Config -> LR: 0.001, Batch: 32, Optimizer: Adam
# Custom: Config -> LR: 0.01, Batch: 64, Optimizer: SGD
# ```

# %%
# TODO: Define build_hyperparameters with defaults and test both calls
def build_hyperparameter(learning_rate = 0.001,batch_size =32,optimizer = "Adam"):
    return f"config -> LR {learning_rate},batch: {batch_size}, Optimizer: {optimizer}"

print("Default: ",build_hyperparameter())
print("Custom: ",build_hyperparameter(learning_rate=0.01,batch_size= 64,optimizer="SGD"))

# %% [markdown]
# ## Section 6: Data Structures (Lists, Tuples, Sets, Dictionaries) & Comprehensions

# %% [markdown]
# ### Exercise 6.1: NLP Dataset Vocabulary List
# Given an initial vocabulary list:
# `vocab = ["<PAD>", "<UNK>", "robot", "data"]`
#
# **Tasks:**
# 1. Append the word `"intelligence"` to the end of `vocab`.
# 2. Replace `"<UNK>"` with `"<START>"` (index 1).
# 3. Remove `"<PAD>"` from the list.
# 4. Print the updated vocabulary and its total word count using `len()`.
#
# **Expected Output:**
# ```text
# Updated Vocab: ['<START>', 'robot', 'data', 'intelligence']
# Vocab Size: 4
# ```

# %%
vocab = ["<PAD>", "<UNK>", "robot", "data"]

# TODO: Append, modify index 1, remove <PAD>, and print updated list & length
vocab.append("intelligence")
vocab[1] = "<start>"
vocab.remove("<PAD>")

print(f"Updated Vocab: {vocab}")
print(f"vocab Size: {len(vocab)}")

# %% [markdown]
# ### Exercise 6.2: Normalized RGB Color Pixel Unpacking
# In image processing, pixels are often represented as normalized `(R, G, B)` tuples between `0.0` and `1.0`:
# `pixel_tuple = (0.2, 0.8, 0.4)`
#
# **Tasks:**
# 1. Unpack `pixel_tuple` into three variables: `red_norm`, `green_norm`, `blue_norm`.
# 2. Scale each channel to 0–255 integer scale by multiplying by 255: `int(channel * 255)`.
# 3. Print the scaled RGB channels.
#
# **Expected Output:**
# ```text
# Scaled RGB: R=51, G=204, B=102
# ```

# %%
pixel_tuple = (0.2, 0.8, 0.4)

# TODO: Unpack pixel_tuple, scale each channel to 0-255 int, and print
red_unpack,green_unpack,blue_unpack= pixel_tuple
red = int(red_unpack * 255)
green = int(green_unpack * 255)
blue = int(blue_unpack * 255)

print(f"Scaled RGB: R={red}, G={green}, B={blue}")

# %% [markdown]
# ### Exercise 6.3: Candidate Skill Matching with Sets
# Two sets represent job requirements and a candidate's profile:
# `required_skills = {"Python", "SQL", "Machine Learning", "Git"}`
# `candidate_skills = {"Python", "Git", "Java", "Docker"}`
#
# **Tasks:**
# 1. Find matching skills using **Intersection** (`required_skills & candidate_skills`).
# 2. Find all distinct skills combined using **Union** (`required_skills | candidate_skills`).
# 3. Find missing skills needed by the candidate using **Difference** (`required_skills - candidate_skills`).
# 4. Print all three sets (sorted for easy reading).
#
# **Expected Output:**
# ```text
# Matching Skills: ['Git', 'Python']
# All Combined Skills: ['Docker', 'Git', 'Java', 'Machine Learning', 'Python', 'SQL']
# Missing Required Skills: ['Machine Learning', 'SQL']
# ```

# %%
required_skills = {"Python", "SQL", "Machine Learning", "Git"}
candidate_skills = {"Python", "Git", "Java", "Docker"}

# TODO: Compute intersection, union, and difference, then print
intersection = required_skills & candidate_skills
union = required_skills | candidate_skills
difference = required_skills - candidate_skills

print(f"Matching skills: {sorted(list(intersection))}")
print(f"Combined Skills :{sorted(list(union))}")
print(f"missing required skills : {sorted(list(difference))}")
# Out:
# Matching skills: ['Git', 'Python']
# Combined Skills :['Docker', 'Git', 'Java', 'Machine Learning', 'Python', 'SQL']
# missing required skills : ['Machine Learning', 'SQL']

# %% [markdown]
# ### Exercise 6.4: AI Agent Profile Dictionary
# Given a dictionary defining an AI assistant agent:
# ```python
# agent_profile = {
#     "name": "Aura",
#     "model": "Gemini-2.0",
#     "temperature": 0.7
# }
# ```
#
# **Tasks:**
# 1. Access and print the agent's `"name"` and `"model"`.
# 2. Add a new setting `"max_tokens": 2048`.
# 3. Update `"temperature"` to `0.2` (making responses more deterministic).
# 4. Iterate over `agent_profile.items()` and print each configuration setting.
#
# **Expected Output:**
# ```text
# Agent Name: Aura | Base Model: Gemini-2.0
# --- Configuration Summary ---
# name = Aura
# model = Gemini-2.0
# temperature = 0.2
# max_tokens = 2048
# ```

# %%
agent_profile = {
    "name": "Aura",
    "model": "Gemini-2.0",
    "temperature": 0.7
}

# TODO: Access keys, add max_tokens, update temperature, and iterate over items()
print(f"Agent name: {agent_profile["name"]} | Base Model: {agent_profile["model"]}")

print("----configuration summary-----")

agent_profile["max_tokens"] = 2048
agent_profile["temperature"] = 0.2

for key,value in agent_profile.items():
    print(f"{key} = {value}")
# Out:
# Agent name: Aura | Base Model: Gemini-2.0
# ----configuration summary-----
# name = Aura
# model = Gemini-2.0
# temperature = 0.2
# max_tokens = 2048

# %% [markdown]
# ### Exercise 6.5: Sensor Signal Filter (List Comprehensions)
# Given a list of noisy sensor readings:
# `signals = [-5, 12, 0, -8, 25, 30, -3, 18]`
#
# **Tasks:**
# 1. Use a list comprehension with an `if` condition to keep only **positive readings** (`s > 0`).
# 2. Use a list comprehension to **double** each of those positive readings (`s * 2`).
# 3. Print both resulting lists.
#
# **Expected Output:**
# ```text
# Positive signals: [12, 25, 30, 18]
# Amplified signals: [24, 50, 60, 36]
# ```

# %%
signals = [-5, 12, 0, -8, 25, 30, -3, 18]

# TODO: Filter positive signals and compute amplified signals using list comprehensions
positive_signals = [s for s in signals if s>0]
double_signals = [s*2  for s in positive_signals]

print(f"Positive Signals: {positive_signals}")
print(f"double_signals: {double_signals}")
# Out:
# Positive Signals: [12, 25, 30, 18]
# double_signals: [24, 50, 60, 36]

# %% [markdown]
# ---
# # 📙 Part 3: Advanced Python & File Processing (Class 4)
#
# Functional programming (`lambda`, `map`, `filter`), set comprehensions, file operations (`.txt`, `.csv`, `.json`), error handling, and regex.

# %% [markdown]
# ## Section 7: Functional Programming (`lambda`, `map`, `filter`) & Set Comprehensions

# %% [markdown]
# ### Exercise 7.1: Lambda Discount Calculator
# Create a lambda function `apply_discount` that takes `(price, discount_percent)` and returns the discounted price:
# $$\text{price} \times (1 - \frac{\text{discount\_percent}}{100})$$
#
# - Test with `apply_discount(200, 15)` (15% off $200).
# - Print the result rounded to 2 decimals.
#
# **Expected Output:**
# ```text
# Discounted Price: $170.00
# ```

# %%
# TODO: Define lambda function apply_discount and test with price 200, discount 15
apply_discount = lambda price,discount_percent: price * (1-(discount_percent/100))
result = apply_discount(200,15)
print(f"Discount Price :${result}")
# Out:
# Discount Price :$170.00

# %% [markdown]
# ### Exercise 7.2: Feature Header Normalization with `map()`
# In data preprocessing, column names often need standardizing:
# `raw_headers = ["  AGE  ", "  ANNUAL_INCOME  ", "  CREDIT_SCORE  ", "  LOAN_STATUS  "]`
#
# **Tasks:**
# - Use `map()` with a lambda function to clean each header: strip whitespace and convert to lowercase (`.strip().lower()`).
# - Convert the result to a list and print it.
#
# **Expected Output:**
# ```text
# Normalized Headers: ['age', 'annual_income', 'credit_score', 'loan_status']
# ```

# %%
raw_headers = ["  AGE  ", "  ANNUAL_INCOME  ", "  CREDIT_SCORE  ", "  LOAN_STATUS  "]

# TODO: Use map() with lambda to strip and lowercase headers
result = list(map(lambda header: header.strip().lower(),raw_headers))

print(f"normalizer headers {result}")
# Out:
# normalizer headers ['age', 'annual_income', 'credit_score', 'loan_status']

# %% [markdown]
# ### Exercise 7.3: Outlier Latency Filter with `filter()`
# A web API monitoring system records request response latencies in milliseconds:
# `latencies_ms = [12, 18, 250, 15, 320, 22, 14, 19, 150]`
#
# **Tasks:**
# - Use `filter()` and a lambda function to filter out outliers, keeping only fast requests where `latency < 100` ms.
# - Convert the result to a list and print it.
#
# **Expected Output:**
# ```text
# Normal Latencies (< 100ms): [12, 18, 15, 22, 14, 19]
# ```

# %%
latencies_ms = [12, 18, 250, 15, 320, 22, 14, 19, 150]

# TODO: Use filter() with lambda to keep latencies < 100ms
filterd_output = list(filter(lambda x : x<100,latencies_ms))
print(f"Normal Latencies: {filterd_output}")
# Out:
# Normal Latencies: [12, 18, 15, 22, 14, 19]

# %% [markdown]
# ### Exercise 7.4: Extracting Unique File Extensions (Set Comprehension)
# Given a list of uploaded raw files:
# `uploaded_files = ["data.csv", "image1.png", "weights.pt", "test.csv", "image2.PNG", "config.json", "data2.CSV"]`
#
# **Tasks:**
# - Use a **set comprehension** to extract the file extension in lowercase: `file.split(".")[-1].lower()`.
# - Print the sorted list of unique extensions.
#
# **Expected Output:**
# ```text
# Unique File Extensions: ['csv', 'json', 'png', 'pt']
# ```

# %%
uploaded_files = ["data.csv", "image1.png", "weights.pt", "test.csv", "image2.PNG", "config.json", "data2.CSV"]

# TODO: Use set comprehension to extract unique lowercase file extensions
unique = {file.split(".")[-1].lower() for file in uploaded_files}
print(f"unique file extensions :{sorted(unique)}")
# Out:
# unique file extensions :['csv', 'json', 'png', 'pt']

# %% [markdown]
# ## Section 8: File Handling (`.txt`, `.csv`, `.json`)

# %% [markdown]
# ### Exercise 8.1: Writing & Reading an AI Training Log (`.txt`)
# 1. Write two training status log entries to `model_training.log` using `with open("model_training.log", "w")`:
#    - Entry 1: `"[INFO] Epoch 1 completed: Loss = 0.45, Accuracy = 88.2%\n"`
#    - Entry 2: `"[INFO] Epoch 2 completed: Loss = 0.32, Accuracy = 92.5%\n"`
# 2. Open and read `model_training.log` using `with open("model_training.log", "r")`, and print the lines.
#
# **Expected Output:**
# ```text
# --- Reading model_training.log ---
# [INFO] Epoch 1 completed: Loss = 0.45, Accuracy = 88.2%
# [INFO] Epoch 2 completed: Loss = 0.32, Accuracy = 92.5%
# ```

# %%
# TODO: Write to model_training.log, then read and print its content
with open("model_training.log", "w") as f:
    f.write("[INFO] Epoch 1 completed: Loss = 0.45, Accuracy = 88.2%\n")
    f.write("[INFO] Epoch 2 completed: Loss = 0.32, Accuracy = 92.5%\n")

print("--- Reading model_training.log ---")
with open("model_training.log", "r") as f:
    print(f.read(), end="")
# Out:
# --- Reading model_training.log ---
# [INFO] Epoch 1 completed: Loss = 0.45, Accuracy = 88.2%
# [INFO] Epoch 2 completed: Loss = 0.32, Accuracy = 92.5%

# %% [markdown]
# ### Exercise 8.2: Model Benchmark Table (`.csv` with `csv` module)
# 1. Write a CSV file named `benchmarks.csv` containing ML model benchmarks:
#    - Header: `["Model", "Latency_ms", "Accuracy"]`
#    - Row 1: `["ResNet-50", "45", "92.4%"]`
#    - Row 2: `["MobileNet", "14", "88.1%"]`
#    - Row 3: `["VisionTransformer", "78", "95.6%"]`
# 2. Read back `benchmarks.csv` using `csv.DictReader` and print each model's name and latency.
#
# **Expected Output:**
# ```text
# --- Model Benchmarks ---
# Model: ResNet-50 | Latency: 45 ms
# Model: MobileNet | Latency: 14 ms
# Model: VisionTransformer | Latency: 78 ms
# ```

# %%
import csv

# TODO: Write benchmarks.csv using csv.writer, then read using csv.DictReader
with open("benchmarks.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["Model", "Latency_ms", "Accuracy"])
    writer.writerow(["ResNet-50", "45", "92.4%"])
    writer.writerow(["MobileNet", "14", "88.1%"])
    writer.writerow(["VisionTransformer", "78", "95.6%"])

# Read benchmarks.csv
print("--- Model Benchmarks ---")
with open("benchmarks.csv", "r") as f:
    reader = csv.DictReader(f)
    for row in reader:
        print(f"Model: {row['Model']} | Latency: {row['Latency_ms']} ms")
# Out:
# --- Model Benchmarks ---
# Model: ResNet-50 | Latency: 45 ms
# Model: MobileNet | Latency: 14 ms
# Model: VisionTransformer | Latency: 78 ms

# %% [markdown]
# ### Exercise 8.3: Saving & Loading AI Model Hyperparameters (`.json`)
# 1. Create a dictionary of hyperparameters:
# ```python
# pipeline_config = {
#     "pipeline_name": "SentimentAnalysis",
#     "max_sequence_length": 128,
#     "pretrained_weights": "bert-base-uncased",
#     "fine_tuned": True
# }
# ```
# 2. Save it to `pipeline_config.json` with `json.dump(..., indent=4)`.
# 3. Load it back using `json.load()` and print the pipeline name and sequence length.
#
# **Expected Output:**
# ```text
# Loaded Pipeline: SentimentAnalysis
# Max Sequence Length: 128
# ```

# %%
import json

pipeline_config = {
    "pipeline_name": "SentimentAnalysis",
    "max_sequence_length": 128,
    "pretrained_weights": "bert-base-uncased",
    "fine_tuned": True
}

# TODO: Save to pipeline_config.json and load back using json module
with open("pipeline_config.json", "w") as f:
    json.dump(pipeline_config, f, indent=4)

# Load from JSON file
with open("pipeline_config.json", "r") as f:
    loaded_config = json.load(f)
    print(f"Loaded Pipeline: {loaded_config['pipeline_name']}")
    print(f"Max Sequence Length: {loaded_config['max_sequence_length']}")
# Out:
# Loaded Pipeline: SentimentAnalysis
# Max Sequence Length: 128

# %% [markdown]
# ## Section 9: Error Handling (`try - except`)

# %% [markdown]
# ### Exercise 9.1: Safe Feature Division (`ZeroDivisionError`)
# In feature engineering, dividing two numeric features can crash if the denominator is zero.
# Write a function `safe_feature_ratio(numerator, denominator)`:
# - In `try`: returns `round(numerator / denominator, 2)`
# - In `except ZeroDivisionError`: prints `"Warning: Denominator is 0. Returning 0.0"` and returns `0.0`
# - Test with `safe_feature_ratio(150, 3)` and `safe_feature_ratio(150, 0)`.
#
# **Expected Output:**
# ```text
# Ratio 1: 50.0
# Warning: Denominator is 0. Returning 0.0
# Ratio 2: 0.0
# ```

# %%
# TODO: Define safe_feature_ratio(numerator, denominator) with try-except
def safe_feature_ratio(numerator, denominator):
    try:
        return round(numerator / denominator, 2)
    except ZeroDivisionError:
        print("Warning: Denominator is 0. Returning 0.0")
        return 0.0

# Test cases
ratio1 = safe_feature_ratio(150, 3)
print(f"Ratio 1: {ratio1}")

ratio2 = safe_feature_ratio(150, 0)
print(f"Ratio 2: {ratio2}")
# Out:
# Ratio 1: 50.0
# ...
# Ratio 2: 0.0

# %% [markdown]
# ### Exercise 9.2: Safe Numeric Sensor Parser (`ValueError`)
# Write a function `parse_sensor_reading(raw_val)`:
# - In `try`: converts `raw_val` to `float` and returns it.
# - In `except ValueError`: prints `f"Error: Cannot parse reading '{raw_val}' as numeric."` and returns `None`.
# - Test with `"74.5"` and `"CORRUPTED_SIGNAL"`.
#
# **Expected Output:**
# ```text
# Parsed Reading: 74.5
# Error: Cannot parse reading 'CORRUPTED_SIGNAL' as numeric.
# Parsed Reading: None
# ```

# %%
# TODO: Define parse_sensor_reading(raw_val) with try-except
def parse_sensor_reading(raw_val):
    try:
        return float(raw_val)
    except ValueError:
        print(f"Error: Cannot parse reading '{raw_val}' as numeric.")
        return None

# Test cases
reading1 = parse_sensor_reading("74.5")
print(f"Parsed Reading: {reading1}")

reading2 = parse_sensor_reading("CORRUPTED_SIGNAL")
print(f"Parsed Reading: {reading2}")
# Out:
# Parsed Reading: 74.5
# Error: Cannot parse reading 'CORRUPTED_SIGNAL' as numeric.
# Parsed Reading: None

# %% [markdown]
# ## Section 10: String Formatting, Modules & Regular Expressions

# %% [markdown]
# ### Exercise 10.1: Model Evaluation Card with f-Strings
# Given evaluation metrics:
# - `model_name = "RandomForestClassifier"`
# - `f1_score = 0.9428`
# - `inference_time_sec = 0.0345`
#
# Print a summary card using f-strings:
# - Model Name
# - F1-Score formatted as a percentage with 2 decimals (`{f1_score:.2%}`)
# - Inference time formatted to 3 decimals (`{inference_time_sec:.3f}s`)
#
# **Expected Output:**
# ```text
# [EVALUATION] Model: RandomForestClassifier | F1-Score: 94.28% | Latency: 0.035s
# ```

# %%
model_name = "RandomForestClassifier"
f1_score = 0.9428
inference_time_sec = 0.0345

# TODO: Print evaluation card using f-strings with formatting
print(f"[EVALUATION] Model: {model_name} | F1-Score: {f1_score:.2%} | Latency: {inference_time_sec:.3f}s")
# Out:
# [EVALUATION] Model: RandomForestClassifier | F1-Score: 94.28% | Latency: 0.035s

# %% [markdown]
# ### Exercise 10.2: Distance Calculation with `math` Module
# Import the `math` module (or `sqrt` and `pow`):
# Calculate the Euclidean distance between two 2D points: $P_1(2, 3)$ and $P_2(6, 7)$ using the distance formula:
# $$d = \sqrt{(x_2 - x_1)^2 + (y_2 - y_1)^2}$$
#
# Print the distance rounded to 2 decimal places.
#
# **Expected Output:**
# ```text
# Euclidean Distance: 5.66
# ```

# %%
import math

x1, y1 = 2, 3
x2, y2 = 6, 7

# TODO: Compute euclidean distance using math.sqrt and print rounded to 2 decimals
distance = math.sqrt((x2 - x1) ** 2 + (y2 - y1) ** 2)
print(f"Euclidean Distance: {round(distance, 2)}")
# Out:
# Euclidean Distance: 5.66

# %% [markdown]
# ### Exercise 10.3: Server Access Log Extraction with Regex (`re`)
# Given a server access log string:
# `log_data = "User [ID:402] accessed file [data_v1.csv] with status [SUCCESS] at latency [45ms]."`
#
# **Tasks:**
# 1. Import `re`.
# 2. Use `re.findall(r"\[(.*?)\]", log_data)` to extract all items inside square brackets `[...]`.
# 3. Print the list of extracted items.
#
# **Expected Output:**
# ```text
# Extracted Log Tokens: ['ID:402', 'data_v1.csv', 'SUCCESS', '45ms']
# ```

# %%
import re

log_data = "User [ID:402] accessed file [data_v1.csv] with status [SUCCESS] at latency [45ms]."

# TODO: Use re.findall to extract all bracketed tokens [...] from log_data and print

extracted_tokens = re.findall(r"\[(.*?)\]", log_data)
print(f"Extracted Log Tokens: {extracted_tokens}")
# Out:
# Extracted Log Tokens: ['ID:402', 'data_v1.csv', 'SUCCESS', '45ms']

# %% [markdown]
# ---
# ## 🎉 Congratulations!
# You have successfully completed **Assignment 2**! You applied core and advanced Python concepts to practical, real-world data science & AI scenarios:
# - ✅ LLM Token Cost & Uptime Computations
# - ✅ Data Cleaning & Image Filename Standardization
# - ✅ GPU Health & Thermal Monitoring Conditions
# - ✅ Training Epochs, Drone Battery, and Early Stopping Loops
# - ✅ Custom Evaluation & Hyperparameter Functions
# - ✅ Vocabularies, RGB Pixels, Skill Match Sets, and Agent Profiles
# - ✅ Functional Transformers (`map`, `filter`), Set Comprehensions
# - ✅ Log File, CSV Benchmarks, and JSON Hyperparameter Handlers
# - ✅ Safe Feature Engineering Division with `try-except`
# - ✅ Metric Cards, Euclidean Distance (`math`), and Log Token Scrapers (`re`)
#
# Awesome job building your real-world Python foundation for Machine Learning! 🚀
